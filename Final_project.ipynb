# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as pt

# %%
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Data_Analytics\Final_Project\global_climate_change_extreme_weather_2026_new.csv")

# %%
df.head()
# Out:
#   record_id        country         region  avg_temperature_c  \
# 0   CLM0001         Canada  North America               16.8
# 1   CLM0002         Brazil  South America               28.8
# 2   CLM0003      Australia        Oceania                6.6
# 3   CLM0004        Germany         Europe               10.9
# 4   CLM0005  United States  North America               13.9
#
#    temperature_change_c  co2_emissions_mt  sea_level_rise_mm flood_risk  \
# 0                  2.40            5477.0               1.44        Low
# 1                  1.51            3758.0               1.55     Medium
# 2                  1.70            1904.0               5.81     Medium
# 3                  1.53            3786.0               5.41     Medium
# 4                  2.07             732.0               3.20       High
#
#   drought_risk  heatwave_days  wildfire_incidents  rainfall_change_mm  \
# 0         High            9.0                25.0                -117
# ...

# %%
df.shape
# Out:
# (5000, 16)

# %%
# Dataset has 5000 rows and 16 columns in total

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   record_id              5000 non-null   str
#  1   country                5000 non-null   str
#  2   region                 5000 non-null   str
#  3   avg_temperature_c      4998 non-null   float64
#  4   temperature_change_c   4999 non-null   float64
#  5   co2_emissions_mt       4997 non-null   float64
#  6   sea_level_rise_mm      5000 non-null   float64
#  7   flood_risk             5000 non-null   str
#  8   drought_risk           5000 non-null   str
#  9   heatwave_days          4998 non-null   float64
#  10  wildfire_incidents     4999 non-null   float64
#  11  rainfall_change_mm     5000 non-null   int64
#  12  air_quality_index      5000 non-null   int64
#  13  climate_risk_score     4999 non-null   float64
#  14  population_affected_m  5000 non-null   float64
# ...

# %%
# Used df.info() to find the datatypes of each column.

# %%
df.describe()
# Out:
#        avg_temperature_c  temperature_change_c  co2_emissions_mt  \
# count        4998.000000           4999.000000       4997.000000
# mean           17.491457              1.493745       3144.870923
# std             7.204215              0.576350       1640.154260
# min             5.000000              0.500000        301.000000
# 25%            11.300000              0.990000       1708.000000
# 50%            17.400000              1.480000       3171.000000
# 75%            23.800000              1.990000       4552.000000
# max            30.000000              2.500000       5999.000000
#
#        sea_level_rise_mm  heatwave_days  wildfire_incidents  \
# count         5000.00000    4998.000000         4999.000000
# mean             3.49663      32.410764          148.320864
# std              1.42864      16.262577           87.615682
# min              1.00000       5.000000            0.000000
# 25%              2.26000      18.000000           70.000000
# ...

# %%
# df.describe() is used to find out the statistical summary of the dataset,

# %%
df
# Out:
#      record_id         country         region  avg_temperature_c  \
# 0      CLM0001          Canada  North America               16.8
# 1      CLM0002          Brazil  South America               28.8
# 2      CLM0003       Australia        Oceania                6.6
# 3      CLM0004         Germany         Europe               10.9
# 4      CLM0005   United States  North America               13.9
# ...        ...             ...            ...                ...
# 4995   CLM4996          Brazil  South America               18.4
# 4996   CLM4997          Canada  North America                8.5
# 4997   CLM4998  United Kingdom         Europe               19.4
# 4998   CLM4999           China           Asia               13.7
# 4999   CLM5000  United Kingdom         Europe                7.2
#
#       temperature_change_c  co2_emissions_mt  sea_level_rise_mm flood_risk  \
# 0                     2.40            5477.0               1.44        Low
# ...

# %%
df.isnull().sum()
# Out:
# record_id                0
# country                  0
# region                   0
# avg_temperature_c        2
# temperature_change_c     1
# co2_emissions_mt         3
# sea_level_rise_mm        0
# flood_risk               0
# drought_risk             0
# heatwave_days            2
# wildfire_incidents       1
# rainfall_change_mm       0
# air_quality_index        0
# climate_risk_score       1
# population_affected_m    0
# year                     0
# dtype: int64
